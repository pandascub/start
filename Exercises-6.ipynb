# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
# from IPython.core.display import HTML
# css = open('style-table.css').read() + open('style-notebook.css').read()
# HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
sales1 = pd.read_csv('~/documents/data/sales1.csv')
sales1
# Out:
#                          Book title  Number sold  Sales price  Royalty paid
# 0            The Bricklayer’s Bible            8         2.99          0.55
# 1                          Swimrand            2         1.99          0.35
# 2  Pining For The Fisheries of Yore           28         2.99          0.55
# 3                The Duck Goes Here           34         2.99          0.55
# 4       The Tower Commission Report            4        11.50          4.25

# %%
sales2 = pd.read_csv('~/documents/data/sales2.csv')
sales2.fillna('') #Replacing NaN (not a number with blanks)
# Out:
#                                Title Units sold List price Royalty
# 0
# 1                Sales report for Q4
# 2             E-Book Reader US Store
# 3   Pining for the Fisheries of Yore       80.0        3.5   14.98
# 4                           Swimrand        1.0       2.99    0.14
# 5             The Bricklayer's Bible       17.0        3.5    5.15
# 6                 The Duck Goes Here       34.0       2.99    5.78
# 7        The Tower Commission Report        4.0        9.5     6.2
# 8                 US royalties (USD)                         32.25
# 9
# 10
# 11               Sales report for Q4
# 12            E-Book Reader UK Store
# 13  Pining for the Fisheries of Yore       47.0       2.99   11.98
# 14            The Bricklayer's Bible       17.0       2.99     3.5
# 15       The Tower Commission Report        4.0        6.5     4.8
# 16                UK royalties (GBP)                         20.28
# 17
# 18
# 19               Sales report for Q4
# ...

# %%
t = sales2
col = sales2.Title.str.extract(r'\((.*)\)')
col
t['currency'] = col
t
#t.fillna(method='ffill') #fffil --forwardfill method: If there is a blank, fill with the last value. 
#This is the opposite of whwat we want. We want to copy UPWARD because USD is a total at the books sold in USD
#sales2.fillna(method='bfill')
#That's what we wanted but we're backfilling everything. Just want to backfill currency and set sales's currency col 
#equal to col
t['currency'] = col.fillna(method='bfill')
t
t = t[t['Units sold'].notnull()]
t
# Out:
#                                Title  Units sold  List price  Royalty currency
# 3   Pining for the Fisheries of Yore        80.0        3.50    14.98      USD
# 4                           Swimrand         1.0        2.99     0.14      USD
# 5             The Bricklayer's Bible        17.0        3.50     5.15      USD
# 6                 The Duck Goes Here        34.0        2.99     5.78      USD
# 7        The Tower Commission Report         4.0        9.50     6.20      USD
# 13  Pining for the Fisheries of Yore        47.0        2.99    11.98      GBP
# 14            The Bricklayer's Bible        17.0        2.99     3.50      GBP
# 15       The Tower Commission Report         4.0        6.50     4.80      GBP
# 21                          Swimrand         8.0        1.99     0.88      EUR
# 22                The Duck Goes Here        12.0        1.99     1.50      EUR

# %% [markdown]
# ### Challenge: first combine these sales together into a single dataframe, then compute how much money consumers spent on each book in each currency.

# %%
s = sales1

s = s.rename(columns={'Book title': 'Title', 'Number sold': 'Units', 'Sales price': 'Price', 'Royalty paid': 'Royalty' })
s['currency'] = 'USD'
s
# Out:
#                               Title  Units  Price  Royalty currency
# 0            The Bricklayer’s Bible      8   2.99     0.55      USD
# 1                          Swimrand      2   1.99     0.35      USD
# 2  Pining For The Fisheries of Yore     28   2.99     0.55      USD
# 3                The Duck Goes Here     34   2.99     0.55      USD
# 4       The Tower Commission Report      4  11.50     4.25      USD

# %%
t = t.rename(columns={'Units sold': 'Units', 'List price': 'Price'})
t.head(100)
# Out:
#                                Title  Units  Price  Royalty currency
# 3   Pining for the Fisheries of Yore   80.0   3.50    14.98      USD
# 4                           Swimrand    1.0   2.99     0.14      USD
# 5             The Bricklayer's Bible   17.0   3.50     5.15      USD
# 6                 The Duck Goes Here   34.0   2.99     5.78      USD
# 7        The Tower Commission Report    4.0   9.50     6.20      USD
# 13  Pining for the Fisheries of Yore   47.0   2.99    11.98      GBP
# 14            The Bricklayer's Bible   17.0   2.99     3.50      GBP
# 15       The Tower Commission Report    4.0   6.50     4.80      GBP
# 21                          Swimrand    8.0   1.99     0.88      EUR
# 22                The Duck Goes Here   12.0   1.99     1.50      EUR

# %%
# col = sales2.Title.str.extract(r'\((.*))\)')
# Challenge: first combine these sales together into a single dataframe,
# then compute how much money consumers spent on each book in each currency.

# %%
new = pd.concat([s,t]) #on=['Title','Price']
new
# new
# #c = c.merge(cast, on=['title','year'])
# #sales_merge.head()
# new.assign(total_paid=new.Price * new.Units)
# new = new.assign(total_spent=lambda new: new.Price*new.Units)
# new
# new.groupby(['Title', 'currency'])['total_spent'].sum()

# #df.groupby(["state", "gender"])["last_name"].count()
# Out:
#                                Title  Units  Price  Royalty currency
# 0             The Bricklayer’s Bible    8.0   2.99     0.55      USD
# 1                           Swimrand    2.0   1.99     0.35      USD
# 2   Pining For The Fisheries of Yore   28.0   2.99     0.55      USD
# 3                 The Duck Goes Here   34.0   2.99     0.55      USD
# 4        The Tower Commission Report    4.0  11.50     4.25      USD
# 3   Pining for the Fisheries of Yore   80.0   3.50    14.98      USD
# 4                           Swimrand    1.0   2.99     0.14      USD
# 5             The Bricklayer's Bible   17.0   3.50     5.15      USD
# 6                 The Duck Goes Here   34.0   2.99     5.78      USD
# 7        The Tower Commission Report    4.0   9.50     6.20      USD
# 13  Pining for the Fisheries of Yore   47.0   2.99    11.98      GBP
# 14            The Bricklayer's Bible   17.0   2.99     3.50      GBP
# 15       The Tower Commission Report    4.0   6.50     4.80      GBP
# ...

# %%
new.head()
#newindexed = new.groupby(['Title', 'currency']).sum()
#newindexed = new.groupby(['Title'])
#newindexed
# Out:
#                               Title  Units  Price  Royalty currency  \
# 0            The Bricklayer’s Bible    8.0   2.99     0.55      USD
# 1                          Swimrand    2.0   1.99     0.35      USD
# 2  Pining For The Fisheries of Yore   28.0   2.99     0.55      USD
# 3                The Duck Goes Here   34.0   2.99     0.55      USD
# 4       The Tower Commission Report    4.0  11.50     4.25      USD
#
#    total_spent
# 0        23.92
# 1         3.98
# 2        83.72
# 3       101.66
# 4        46.00

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [186], in <cell line: 1>()
# ----> 1 new.groupby(['Title', 'currency']).agg({'total_spent': np.sum})
#
# NameError: name 'np' is not defined

# %%
new
#newindexed.index.str.strip
# Out:
#                                Title  Units  Price  Royalty currency  \
# 0             The Bricklayer’s Bible    8.0   2.99     0.55      USD
# 1                           Swimrand    2.0   1.99     0.35      USD
# 2   Pining For The Fisheries of Yore   28.0   2.99     0.55      USD
# 3                 The Duck Goes Here   34.0   2.99     0.55      USD
# 4        The Tower Commission Report    4.0  11.50     4.25      USD
# 3   Pining for the Fisheries of Yore   80.0   3.50    14.98      USD
# 4                           Swimrand    1.0   2.99     0.14      USD
# 5             The Bricklayer's Bible   17.0   3.50     5.15      USD
# 6                 The Duck Goes Here   34.0   2.99     5.78      USD
# 7        The Tower Commission Report    4.0   9.50     6.20      USD
# 13  Pining for the Fisheries of Yore   47.0   2.99    11.98      GBP
# 14            The Bricklayer's Bible   17.0   2.99     3.50      GBP
# 15       The Tower Commission Report    4.0   6.50     4.80      GBP
# ...

# %%
#new.groupby(['Title', 'currency', as_index=False]).agg({'total_spent': np.sum})
new.groupby(['Title', 'currency'], as_index=False)['total_spent'].sum()
new_index = new.set_index(['Title'], append = False)
new_index
new_index = new_index.index.str.strip()
# Out:
# Index(['The Bricklayer’s Bible', 'Swimrand',
#        'Pining For The Fisheries of Yore', 'The Duck Goes Here',
#        'The Tower Commission Report', 'Pining for the Fisheries of Yore',
#        'Swimrand', 'The Bricklayer's Bible', 'The Duck Goes Here',
#        'The Tower Commission Report', 'Pining for the Fisheries of Yore',
#        'The Bricklayer's Bible', 'The Tower Commission Report', 'Swimrand',
#        'The Duck Goes Here'],
#       dtype='object', name='Title')
